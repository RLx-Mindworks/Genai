# %%
# from dotenv import load_dotenv
import os
import json
from google import genai

# %%
GEMINI_API_KEY= "AIzaSyBEBzMqwxeQxivOJ0CLN4J3Q81xRSkE3JI"

# %%
client= genai.Client(api_key=GEMINI_API_KEY)

# %% [markdown]
# ### Generating Content from schema

# %%
json_provision = lambda x,y: x if y==False else json.loads(x)

# %%
def generate_content(prompt, response_schema=False, provide_json=False,model = 'gemini-2.5-flash'):
    
    if response_schema!=False:
        configuration={
            'response_mime_type': 'application/json',
            'response_schema': response_schema
        }
    else:
        configuration={
            'response_mime_type': 'application/json',
        }
    
    response = client.models.generate_content(
        model=model, 
        contents=[prompt],
        config={
            'response_mime_type': 'application/json',
            'response_schema': response_schema,
        }
    )
    if provide_json!=False:
        return json_provision(response.text, True)
    return response

# %% [markdown]
# ### Pydantic Values

# %%
from pydantic import BaseModel, Field
from typing import List

class Stat(BaseModel):
    value: str = Field(..., description="Numerical or textual value representing the stat")
    label: str = Field(..., description="Label describing the meaning of the value")

class Header(BaseModel):
    title: str = Field(..., description="Main title of the newsletter")
    subtitle: str = Field(..., description="Subtitle giving additional context")
    issue: str = Field(..., description="Issue number or identifier")
    date: str = Field(..., description="Publication date in a human-readable format")
    edition: str = Field(..., description="Edition type, e.g., Weekly, Monthly")
    stats: List[Stat] = Field(..., description="List of key statistics displayed in the header")

# %%
from pydantic import BaseModel, Field
from typing import List, Literal

class Header(BaseModel):
    title: Literal["ROUND RAISED"] = Field(
        ..., description="Fixed newsletter title"
    )
    issueNumber: int = Field(
        ..., description="Dynamic issue number for this edition"
    )
    date: str = Field(
        ..., description="Dynamic publication date (e.g. 'JAN DD, YYYY')"
    )

class Editorial(BaseModel):
    content: str = Field(
        ..., description="Editorial intro/content for this issue"
    )

class FundingRound(BaseModel):
    company: str
    description: str
    amount: str
    stage: str
    leadInvestor: str
    details: str = Fieldld(..., description= "where this company is focusing (make it one-liner)")

class MarketData(BaseModel):
    title: Literal["Recent Funding Rounds"] = Field(
        ..., description="Fixed section heading"
    )
    fundingRounds: List[FundingRound] = Field(
        ..., description="List of recently closed rounds"
    )

class Founder(BaseModel):
    name: str
    position: str
    company: str
    background: str
    journey: str

class BusinessFeature(BaseModel):
    title: str
    description: str

class FeaturedCaseStudy(BaseModel):
    title: str
    founder: Founder
    businessFeatures: List[BusinessFeature]
    fundingStory: str

class InvestorSpotlightStats(BaseModel):
    portfolio: str
    focus: str
    checkSize: str = Field(..., alias="checkSize")

class InvestorSpotlight(BaseModel):
    name: str
    position: str
    initials: str
    description: str
    quote: str
    stats: InvestorSpotlightStats

class BusinessMetricStat(BaseModel):
    value: str
    label: str
    description: str

# %% [markdown]
# ### Founder Rows

# %%
class BusinessMetrics(BaseModel):
    title: Literal["Supply Chain Tech Market Pulse"] = Field(
        ..., description="Fixed section heading"
    )
    stats: List[BusinessMetricStat]
    trends: List[str]

class PitchOpportunity(BaseModel):
    name: str
    date: str
    deadline: str
    focus: str
    details: str

# %%
class MarketInsights(BaseModel):
    title: Literal["The Rise of Vertical SaaS in Supply Chain"] = Field(
        ..., description="Fixed section heading"
    )
    content: str
    winners: List[str]
    investmentFocus: List[str]

class CommunityLink(BaseModel):
    platform: str
    description: str
    icon: str
    buttonText: str
    bgColor: str
    iconBg: str

class FeaturedFounder(BaseModel):
    name: str
    age: int
    company: str
    approach: str
    result: str
    lesson: str

class Community(BaseModel):
    featuredFounder: FeaturedFounder
    links: List[CommunityLink]

class NewsletterSection(BaseModel):
    title: Literal["Marketing Led Brands Newsletter"] = Field(
        ..., description="Fixed section heading"
    )
    description: Literal[
        "Get exclusive insights on growth marketing and brand strategies from top companies."
    ] = Field(..., description="Fixed subheading")
    ctaText: Literal["Subscribe Now"] = Field(
        ..., description="Fixed CTA text"
    )

class FooterLink(BaseModel):
    text: str
    href: str

class Footer(BaseModel):
    forwardMessage: str
    subscribeMessage: str
    publisher: str
    contact: str
    links: List[FooterLink]

class Newsletter(BaseModel):
    header: Header
    editorial: Editorial
    marketData: MarketData
    featuredCaseStudy: FeaturedCaseStudy
    investorSpotlight: InvestorSpotlight
    businessMetrics: BusinessMetrics
    pitchOpportunities: List[PitchOpportunity]
    marketInsights: MarketInsights
    community: Community
    newsletter: NewsletterSection
    footer: Footer

# %%
# prompt = """You are helping create the header section of a branded marketing newsletter targeted at 
# college students interested in marketing strategies"""

# %%
prompt = """You are a JSON generator for the “ROUND RAISED” funding‑insights newsletter.  
Using the schema below, produce a complete newsletter JSON. Keep all **frozen** fields exactly as shown; generate fresh values for everything else. Return only valid JSON.

Schema summary:

1. header  
   • title (must be `"ROUND RAISED"`)  
   • issueNumber (integer, next issue number)  
   • date (string, e.g. `"Feb 10, 2025"`)

2. editorial  
   • content (string introduction)

3. marketData  
   • title (must be `"Recent Funding Rounds"`)  
   • fundingRounds (array of objects with company, description, amount, stage, leadInvestor, details)

4. featuredCaseStudy  
   • title, founder (name, position, company, background, journey)  
   • businessFeatures (array of {title, description})  
   • fundingStory (string)

5. investorSpotlight  
   • name, position, initials, description, quote  
   • stats (portfolio, focus, checkSize)

6. businessMetrics  
   • title (must be `"Supply Chain Tech Market Pulse"`)  
   • stats (array of {value, label, description})  
   • trends (array of strings)

7. pitchOpportunities (array of {name, date, deadline, focus, details})

8. marketInsights  
   • title (must be `"The Rise of Vertical SaaS in Supply Chain"`)  
   • content, winners (array), investmentFocus (array)

9. community  
   • featuredFounder (name, age, company, approach, result, lesson)  
   • links (array of {platform, description, icon, buttonText, bgColor, iconBg})

10. newsletter  
    • title (must be `"Marketing Led Brands Newsletter"`)  
    • description (must be `"Get exclusive insights on growth marketing and brand strategies from top companies."`)  
    • ctaText (must be `"Subscribe Now"`)

11. footer  
    • forwardMessage, subscribeMessage, publisher, contact  
    • links (array of {text, href})

**Instructions for generation:**
- Keep **literal** fields exactly as specified above.
- Increment `issueNumber` by 1 from the last known issue.
- Use a realistic, current date for `date`.
- Fill every other field with coherent, engaging, and on‑brand content for a funding‑rounds newsletter.
- Do **not** include any extra keys or commentary—return pure JSON.
"""

# %%
generate_content(prompt, Newsletter,True)
# Out:
# {'header': {'title': 'ROUND RAISED',
#   'issueNumber': 13,
#   'date': 'JUN 25, 2024'},
#  'editorial': {'content': "Welcome to another action-packed edition of ROUND RAISED! This issue dives deep into the dynamic world of venture capital, showcasing significant funding rounds, innovative startups, and key market trends. We're observing robust activity across supply chain tech, with vertical SaaS emerging as a dominant force. Our featured case study highlights a founder's journey to securing capital in a competitive landscape, and we offer actionable insights for both founders seeking investment and investors identifying the next big thing. Stay tuned for expert commentary and exclusive opportunities."},
#  'marketData': {'title': 'Recent Funding Rounds',
#   'fundingRounds': [{'company': 'LogiSync Solutions',
#     'description': 'AI-powered logistics optimization platform for last-mile delivery.',
#     'amount': '$25M',
#     'stage': 'Series B',
#     'leadInvestor': 'Apex Ventures',
#     'details': 'This round will accelerate product development and expand market reach across North America and Europe, focusing on predictive analytics and route optimization.'},
#    {'company': 'GreenChain Innovations',
#     'description': 'Blockchain-enabled platform for sustainable supply chain traceability.',
#     'amount': '$12M',
#     'stage': 'Series A',
#     'leadInvestor': 'Veridian Capital',
#     'details': "Funds will be used to enhance their platform's data integrity features and integrate with more enterprise ERP systems, supporting ESG compliance for global brands."},
#    {'company': 'RoboFlow Automation',
#     'description': 'Robotics-as-a-Service (RaaS) provider for automated warehouse operations.',
#     'amount': '$40M',
#     'stage': 'Series C',
#     'leadInvestor': 'Quantum Growth Partners',
#     'details': 'The investment aims to scale their robotic fleet and expand their presence in e-commerce fulfillment centers, leveraging advanced machine learning for adaptive operations.'}]},
#  'featuredCaseStudy': {'title': 'From Concept to Capital: The Story of NexTrack Logistics',
#   'founder': {'name': 'Sarah Chen',
#    'position': 'CEO & Co-founder',
#    'company': 'NexTrack Logistics',
#    'background': 'Sarah, a former supply chain executive at a Fortune 500 company, observed firsthand the inefficiencies plaguing global logistics. Her vision was to create an intuitive, data-driven platform that could provide real-time visibility across complex supply chains.',
#    'journey': 'Starting in her garage with a small team, Sarah bootstrapped NexTrack for the first 18 months, building a robust MVP. She leveraged her extensive industry network to secure early pilot customers, whose feedback proved invaluable. Her persistent networking led her to an angel investor who provided the initial seed capital, validating her concept and paving the way for institutional rounds.'},
#   'businessFeatures': [{'title': 'Real-time Tracking',
#     'description': 'End-to-end visibility of goods in transit, from raw materials to final delivery, reducing delays and improving communication.'},
#    {'title': 'Predictive Analytics',
#     'description': 'AI-driven forecasting of potential disruptions, enabling proactive risk mitigation and optimized inventory management.'},
#    {'title': 'Automated Compliance',
#     'description': 'Streamlined documentation and regulatory adherence, reducing human error and ensuring global trade compliance.'}],
#   'fundingStory': "NexTrack Logistics initially struggled to articulate its unique value proposition to generalist VCs. Sarah meticulously crafted her pitch to emphasize the massive market opportunity within supply chain digitization and her team's deep domain expertise. Her breakthrough came when she connected with a VC firm specializing in logistics tech. They understood the nuances of the industry and saw the immense potential in NexTrack's predictive capabilities. After several rigorous due diligence sessions, NexTrack successfully closed a $10 million Series A round, valuing the company at $50 million, enabling them to expand their engineering team and accelerate customer acquisition. The key was finding investors who truly spoke their language."},
#  'investorSpotlight': {'name': 'David Kim',
#   'position': 'Partner at Horizon Ventures',
#   'initials': 'DK',
#   'description': 'David Kim is a seasoned investor with over 15 years of experience in the venture capital landscape, specializing in early-stage technology companies. He has a keen eye for disruptive innovations and a strong track record of backing successful founders in the enterprise software and logistics sectors. His approach combines deep market analysis with a founder-first philosophy, providing strategic guidance beyond capital.',
#   'quote': 'In a rapidly evolving market, the ability to adapt and iterate is paramount. We look for founders who not only have a compelling vision but also the resilience and agility to navigate unforeseen challenges.',
#   'stats': {'portfolio': '20+ active investments in enterprise SaaS, logistics tech, and AI/ML startups.',
#    'focus': 'Seed to Series B in B2B SaaS, Supply Chain Optimization, and Data Analytics.',
#    'checkSize': '$1M - $10M'}},
#  'businessMetrics': {'title': 'Supply Chain Tech Market Pulse',
#   'stats': [{'value': '$35B',
#     'label': 'Global Market Size',
#     'description': 'Projected market size for supply chain management software by 2027, growing at a CAGR of 10.2%.'},
#    {'value': '45%',
#     'label': 'AI Adoption',
#     'description': 'Increase in AI and ML integration within supply chain operations over the past 12 months, driving efficiency gains.'},
#    {'value': '60%',
#     'label': 'Cloud Migration',
#     'description': 'Of supply chain solutions are now cloud-based, enabling greater flexibility and scalability for enterprises.'}],
#   'trends': ['Increased focus on supply chain resiliency and risk management post-pandemic.',
#    'Growing demand for predictive analytics and AI-driven optimization tools.',
#    'Sustainability and ethical sourcing becoming key drivers for technology adoption.',
#    "Rise of 'control towers' for end-to-end visibility across complex networks."]},
#  'pitchOpportunities': [{'name': 'TechConnect Investor Forum',
#    'date': 'JUL 15, 2024',
#    'deadline': 'JUN 30, 2024',
#    'focus': 'Enterprise SaaS, Fintech, AI',
#    'details': 'An exclusive event connecting pre-seed to Series A startups with over 50 active angel investors and VCs. Pitch slots are competitive.'},
#   {'name': 'Future Logistics Summit - Pitch Competition',
#    'date': 'AUG 01, 2024',
#    'deadline': 'JUL 10, 2024',
#    'focus': 'Supply Chain, Logistics, Mobility',
#    'details': 'Showcase your innovative solutions to a panel of leading logistics corporate VCs and industry leaders. Cash prizes and potential investment opportunities.'},
#   {'name': 'Global Impact Ventures Demo Day',
#    'date': 'SEP 05, 2024',
#    'deadline': 'AUG 15, 2024',
#    'focus': 'Sustainable Tech, ESG, Social Impact',
#    'details': 'Opportunity for startups aligning with UN Sustainable Development Goals to pitch to impact investors and accelerate their growth.'}],
#  'marketInsights': {'title': 'The Rise of Vertical SaaS in Supply Chain',
#   'content': 'Vertical SaaS (Software as a Service) is rapidly gaining traction in the supply chain sector, moving beyond horizontal, one-size-fits-all solutions. This specialized approach offers tailored functionalities, deeper industry insights, and compliance capabilities specific to niches like cold chain logistics, pharmaceutical distribution, or e-commerce fulfillment. By embedding themselves deeply within specific industry workflows, Vertical SaaS companies can deliver immense value, solving unique pain points that generic platforms often miss. This focus allows for superior user experience, faster adoption, and often, higher customer retention rates due to the indispensable nature of the software within that vertical.',
#   'winners': ['Companies providing specialized freight management for hazardous materials.',
#    'Platforms optimizing inventory for perishable goods with real-time spoilage prediction.',
#    'Software for last-mile delivery focused solely on urban environments with drone integration.'],
#   'investmentFocus': ['Solutions addressing specific regulatory challenges within niche supply chains.',
#    'AI/ML-powered platforms for highly specialized forecasting and optimization.',
#    'Companies with strong network effects within their chosen vertical.',
#    'Platforms integrating deeply with existing legacy systems in fragmented industries.']},
#  'community': {'featuredFounder': {'name': "Alex 'The Connector' Reed",
#    'age': 32,
#    'company': 'LinkUp Networks',
#    'approach': "Alex understood that successful fundraising wasn't just about the pitch deck; it was about building genuine relationships. He spent months attending industry events, virtually and in-person, not to pitch directly but to learn, offer value, and make authentic connections with potential investors and advisors. He focused on 'giving before getting.'",
#    'result': 'By the time LinkUp Networks was ready for its Series A, Alex had established warm introductions to nearly all target VCs. His reputation preceded him, and the investors already had a sense of his integrity and vision, leading to an oversubscribed round and a significant valuation uplift.',
#    'lesson': "Networking is not transactional; it's foundational. Build a strong community around you, and opportunities will naturally follow."},
#   'links': [{'platform': 'LinkedIn',
#     'description': 'Connect with us and other founders/investors.',
#     'icon': 'linkedin',
#     'buttonText': 'Join Our Network',
#     'bgColor': '#0077B5',
#     'iconBg': '#005582'},
#    {'platform': 'Slack',
#     'description': 'Exclusive discussions and direct investor access.',
#     'icon': 'slack',
#     'buttonText': 'Join Our Channel',
#     'bgColor': '#4A154B',
#     'iconBg': '#2B0B2C'},
#    {'platform': 'Community Forum',
#     'description': 'Share insights, ask questions, get advice.',
#     'icon': 'forum',
#     'buttonText': 'Access Forum',
#     'bgColor': '#28A745',
#     'iconBg': '#1E7D34'}]},
#  'newsletter': {'title': 'Marketing Led Brands Newsletter',
#   'description': 'Get exclusive insights on growth marketing and brand strategies from top companies.',
#   'ctaText': 'Subscribe Now'},
#  'footer': {'forwardMessage': "Know someone who'd benefit from these insights? Share this newsletter!",
#   'subscribeMessage': "Not yet subscribed? Don't miss out on future editions of ROUND RAISED.",
#   'publisher': 'Round Raised Insights, Inc.',
#   'contact': 'info@roundraised.com',
#   'links': [{'text': 'Privacy Policy',
#     'href': 'https://www.roundraised.com/privacy'},
#    {'text': 'Terms of Service', 'href': 'https://www.roundraised.com/terms'},
#    {'text': 'Unsubscribe',
#     'href': 'https://www.roundraised.com/unsubscribe'}]}}
